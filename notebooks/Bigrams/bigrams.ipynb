# %%
import sys
import os
sys.path.append(os.path.abspath("../../src"))
import data_loader.Bigrams as Data
import logging

# %%
# Configure logging with both file and console handlers
logger = logging.getLogger(__name__)
logger.setLevel(logging.INFO)

file_handler = logging.FileHandler('logs/data_loader.log')
file_handler.setLevel(logging.DEBUG)

console_handler = logging.StreamHandler()
console_handler.setLevel(logging.INFO)

formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
file_handler.setFormatter(formatter)
console_handler.setFormatter(formatter)

logger.addHandler(file_handler)
logger.addHandler(console_handler)

# %%
DATA = Data.Bigrams("../../data/raw/names.txt", logger)
# Out:
# 2026-03-03 11:02:09,935 - __main__ - INFO - Successfully loaded 32033 samples
# 2026-03-03 11:02:09,937 - __main__ - INFO - Dataset statistics - Max length: 15, Min length: 2
